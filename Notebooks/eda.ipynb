# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(style="whitegrid")

# Load the dataset
df = pd.read_csv("../data/Data.csv")
df.head()
# Out:
#     neighborhood  safety_score   rent  parks_score  walk_score
# 0  Koregaon Park             8  22000            9          85
# 1          Baner             7  18000            7          75
# 2          Wakad             6  15000            6          65
# 3      Hinjewadi             5  14000            5          60
# 4   Shivajinagar             8  20000            8          80

# %%
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   neighborhood  5 non-null      object
#  1   safety_score  5 non-null      int64
#  2   rent          5 non-null      int64
#  3   parks_score   5 non-null      int64
#  4   walk_score    5 non-null      int64
# dtypes: int64(4), object(1)
# memory usage: 332.0+ bytes
#        safety_score          rent  parks_score  walk_score
# count       5.00000      5.000000     5.000000    5.000000
# mean        6.80000  17800.000000     7.000000   73.000000
# std         1.30384   3346.640106     1.581139   10.368221
# min         5.00000  14000.000000     5.000000   60.000000
# 25%         6.00000  15000.000000     6.000000   65.000000
# 50%         7.00000  18000.000000     7.000000   75.000000
# 75%         8.00000  20000.000000     8.000000   80.000000
# max         8.00000  22000.000000     9.000000   85.000000

# %%
# Correlation Heatmap

numeric_df = df.select_dtypes(include='number')


plt.figure(figsize=(8, 6))
sns.heatmap(numeric_df.corr(), annot=True, cmap="coolwarm")
plt.title("Feature Correlation Matrix")
plt.show()

# %%
df.hist(bins=20, figsize=(12, 8), color="skyblue", edgecolor="black")
plt.suptitle("Distributions of All Features", y=1.02)
plt.tight_layout()
plt.show()

# %%
# Pairplot of Relationships
sns.pairplot(df[['safety_score', 'rent', 'parks_score', 'walk_score']])
plt.suptitle("Feature Relationships", y=1.02)
plt.show()
